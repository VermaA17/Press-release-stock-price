# %%
import pandas as pd
import json
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()
#jdata = json.loads('C:/Users/ADMIN/Downloads/AMZN_pr.json',encoding='utf-8')
with open('C:/Users/ADMIN/Downloads/AMZN_pr.json', 'r',encoding='utf-8') as myfile:
    data=json.load(myfile)
df = pd.DataFrame(data)
#df = pd.DataFrame.from_dict(data, orient='columns')
#df['title']

#df['content'][1]


content = []
date_count = []
vs_compound = []
vs_pos = []
vs_neu = []
vs_neg = []


for i in range(0, len(df)):
    content.append(df['content'][i])
    date_count.append(df['date'][i])
    vs_compound.append(analyzer.polarity_scores(df['content'][i])['compound'])
    vs_pos.append(analyzer.polarity_scores(df['content'][i])['pos'])
    vs_neu.append(analyzer.polarity_scores(df['content'][i])['neu'])
    vs_neg.append(analyzer.polarity_scores(df['content'][i])['neg'])
   
from pandas import Series, DataFrame
final = DataFrame({'release': content,
                        'date': date_count,
                        'Compound': vs_compound,
                        'Positive': vs_pos,
                        'Neutral': vs_neu,
                        'Negative': vs_neg})
final1=pd.DataFrame(final)
final1.to_csv("AMZN_Senti.csv")
final1
# Out:
#                                               release  \
# 0   \nCalifornia, Arizona, North Carolina, Michiga...
# 1   \nNew 645,000 square-foot site in the city of ...
# 2   \nNew 48,000 square foot tech office is locate...
# 3       SEATTLE--(BUSINESS WIRE)--\nAmazon.com, In...
# 4   NEW YORK, Jan. 14, 2020 /PRNewswire/ -- Invest...
# 5   NEW YORK, Jan. 10, 2020 /PRNewswire/ -- Invest...
# 6    ORLANDO, Fla., Jan. 6, 2020 /PRNewswire/ -- V...
# 7   \nFire TV Edition now powers over 50 TV and so...
# 8    NEW YORK, Jan. 2, 2020 /PRNewswire/ -- Invest...
# 9   NEW YORK, Dec. 27, 2019 /PRNewswire/ -- Invest...
# 10  \nCustomers in the U.S. Enjoyed a Season of Co...
# 11  \nNew this year, customers have at least one f...
# 12      NEWARK, N.J.--(BUSINESS WIRE)--\nAudible, ...
# 13  \nThis season customers can choose from a vari...
# 14  SINGAPORE, Dec. 16, 2019 /PRNewswire/ -- – (NA...
# 15  \nAmazon Offers Last-Minute Shoppers More than...
# 16  \nPrime welcomed more members worldwide this y...
# 17  \nRevival series will bring one of Australia’s...
# 18      SEATTLE--(BUSINESS WIRE)--\n(NASDAQ:AMZN) ...
# 19  \nAmazon Redshift RA3 instances let customers ...
#
#                           date  Compound  Positive  Neutral  Negative
# 0    [Feb 21, 2020 8:00AM EST]    0.9984     0.169    0.820     0.011
# 1     [Feb 6, 2020 8:42AM EST]    0.9990     0.197    0.788     0.015
# 2     [Feb 4, 2020 9:00AM EST]    0.9990     0.178    0.801     0.021
# 3    [Jan 30, 2020 4:01PM EST]    0.9982     0.131    0.835     0.034
# 4    [Jan 14, 2020 9:31AM EST]    0.6808     0.073    0.906     0.021
# 5    [Jan 10, 2020 9:31AM EST]    0.6808     0.072    0.907     0.021
# 6     [Jan 6, 2020 9:00AM EST]    0.9845     0.098    0.869     0.033
# 7     [Jan 6, 2020 9:00AM EST]    0.9990     0.164    0.758     0.078
# 8     [Jan 2, 2020 9:31AM EST]    0.6808     0.073    0.906     0.021
# 9    [Dec 27, 2019 9:31AM EST]    0.6808     0.073    0.906     0.021
# 10   [Dec 26, 2019 3:00AM EST]    0.9984     0.249    0.727     0.025
# 11   [Dec 18, 2019 6:01AM EST]    0.9992     0.201    0.779     0.020
# 12   [Dec 17, 2019 9:00AM EST]    0.9983     0.138    0.850     0.012
# 13   [Dec 17, 2019 3:01AM EST]    0.9988     0.153    0.834     0.013
# 14  [Dec 15, 2019 10:01PM EST]    0.9995     0.238    0.740     0.022
# 15   [Dec 11, 2019 3:00AM EST]    0.9999     0.230    0.761     0.009
# 16    [Dec 5, 2019 3:01AM EST]    0.9996     0.224    0.767     0.010
# 17   [Dec 4, 2019 11:00PM EST]    0.9996     0.195    0.801     0.004
# 18    [Dec 4, 2019 7:36PM EST]   -0.1280     0.058    0.902     0.041
# 19    [Dec 3, 2019 2:16PM EST]    0.9999     0.165    0.819     0.016
